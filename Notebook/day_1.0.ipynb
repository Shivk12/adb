# %% [markdown]
# ###purpose
# 1. Read csv file from adls storage and loading to dataframe

# %%
# dbutils.widgets.text("child_folder","")
child_folder= dbutils.widgets.get("child_folder")
print(child_folder)

# %%
# %run ../Utilities/de_utilities

# %%
# file_path="/Volumes/dltshiv/source/files/emp"
actual_path=f"{folder_path}{child_folder}"
print(folder_path)
print(actual_path)

# %%
#use list_file function
list_files(actual_path)

#Use function read_file
df_csv=read_file(actual_path)
df_csv.display()
